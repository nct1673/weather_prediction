# %%
import pandas as pd
import numpy as np
from datetime import datetime
from zoneinfo import ZoneInfo
from statsmodels.tsa.seasonal import seasonal_decompose

df = pd.read_csv('../data_csv_raw/raw_data.csv')
df.drop_duplicates(inplace=True)
df = df.sort_values(by='dt')
df['utc8'] = pd.to_datetime(df['dt'], unit='s', utc=True).dt.tz_convert('Asia/Kuala_Lumpur')
# df['year']       = df['utc8'].dt.year
df['month']      = df['utc8'].dt.month
# df['day']        = df['utc8'].dt.day
df['hour']       = df['utc8'].dt.hour
df['hour_stan'] = (df['hour'] - df['hour'].min()) / (df['hour'].max() - df['hour'].min())
df
# Out:
#         lat     lon           timezone  timezone_offset          dt  \
# 3040  3.033  101.45  Asia/Kuala_Lumpur            28800  1728748800
# 4614  3.033  101.45  Asia/Kuala_Lumpur            28800  1728752400
# 1777  3.033  101.45  Asia/Kuala_Lumpur            28800  1728756000
# 4004  3.033  101.45  Asia/Kuala_Lumpur            28800  1728759600
# 4645  3.033  101.45  Asia/Kuala_Lumpur            28800  1728763200
# ...     ...     ...                ...              ...         ...
# 2916  3.033  101.45  Asia/Kuala_Lumpur            28800  1749207600
# 4066  3.033  101.45  Asia/Kuala_Lumpur            28800  1749211200
# 4639  3.033  101.45  Asia/Kuala_Lumpur            28800  1749214800
# 2414  3.033  101.45  Asia/Kuala_Lumpur            28800  1749218400
# 4323  3.033  101.45  Asia/Kuala_Lumpur            28800  1749222000
#
#          sunrise      sunset   temp  feels_like  pressure  ...  wind_speed  \
# 3040  1728773914  1728817317  26.01       26.01      1012  ...        1.03
# 4614  1728773914  1728817317  25.98       25.98      1011  ...        1.03
# 1777  1728773914  1728817317  25.84       26.93      1011  ...        1.54
# 4004  1728773914  1728817317  25.47       26.53      1010  ...        0.00
# 4645  1728773914  1728817317  25.24       26.27      1010  ...        0.00
# ...          ...         ...    ...         ...       ...  ...         ...
# 2916  1749164659  1749208900  26.90       28.85      1009  ...        2.37
# 4066  1749164659  1749208900  27.21       30.11      1009  ...        2.57
# 4639  1749164659  1749208900  27.21       30.11      1009  ...        2.06
# 2414  1749164659  1749208900  26.79       29.53      1011  ...        1.03
# 4323  1749164659  1749208900  26.79       29.53      1011  ...        1.03
#
#       wind_deg  weather_id  weather_main          weather_desc  weather_icon  \
# 3040         0         500          Rain            light rain           10n
# 4614         0         801        Clouds            few clouds           02n
# 1777         0         801        Clouds            few clouds           02n
# 4004         0         502          Rain  heavy intensity rain           10n
# 4645         0         501          Rain         moderate rain           10n
# ...        ...         ...           ...                   ...           ...
# 2916       346         804        Clouds       overcast clouds           04d
# 4066       280         801        Clouds            few clouds           02n
# 4639       330         500          Rain            light rain           10n
# 2414         0         500          Rain            light rain           10n
# 4323         0         500          Rain            light rain           10n
#
#                           utc8  month hour hour_stan
# 3040 2024-10-13 00:00:00+08:00     10    0  0.000000
# 4614 2024-10-13 01:00:00+08:00     10    1  0.043478
# 1777 2024-10-13 02:00:00+08:00     10    2  0.086957
# 4004 2024-10-13 03:00:00+08:00     10    3  0.130435
# 4645 2024-10-13 04:00:00+08:00     10    4  0.173913
# ...                        ...    ...  ...       ...
# 2916 2025-06-06 19:00:00+08:00      6   19  0.826087
# 4066 2025-06-06 20:00:00+08:00      6   20  0.869565
# 4639 2025-06-06 21:00:00+08:00      6   21  0.913043
# 2414 2025-06-06 22:00:00+08:00      6   22  0.956522
# 4323 2025-06-06 23:00:00+08:00      6   23  1.000000
#
# [5858 rows x 25 columns]

# %%
df['weather_main'].unique()
# Out:
# array(['Rain', 'Thunderstorm', 'Clouds', 'Smoke', 'Mist', 'Clear', 'Haze'],
#       dtype=object)

# %%
0 * * * * /bin/bash -c "source /home/chen/anaconda3/etc/profile.d/conda.sh && conda activate pt && python try_getcurrent.py >> /home/chen/Desktop/weather/log.txt 2>&1"
