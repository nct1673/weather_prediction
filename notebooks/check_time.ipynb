# %%
import pandas as pd
import numpy as np
from datetime import datetime
from zoneinfo import ZoneInfo
from statsmodels.tsa.seasonal import seasonal_decompose

df = pd.read_csv('../data_csv_raw/raw_data.csv')
df.drop_duplicates(inplace=True)
df = df.sort_values(by='dt')
df['utc8'] = pd.to_datetime(df['dt'], unit='s', utc=True).dt.tz_convert('Asia/Kuala_Lumpur')
# df['year']       = df['utc8'].dt.year
df['month']      = df['utc8'].dt.month
# df['day']        = df['utc8'].dt.day
df['hour']       = df['utc8'].dt.hour
df['hour_stan'] = (df['hour'] - df['hour'].min()) / (df['hour'].max() - df['hour'].min())
df
# Out:
#         lat     lon           timezone  timezone_offset          dt  \
# 841   3.033  101.45  Asia/Kuala_Lumpur            28800  1735660800
# 2516  3.033  101.45  Asia/Kuala_Lumpur            28800  1735664400
# 2363  3.033  101.45  Asia/Kuala_Lumpur            28800  1735668000
# 1988  3.033  101.45  Asia/Kuala_Lumpur            28800  1735671600
# 466   3.033  101.45  Asia/Kuala_Lumpur            28800  1735675200
# ...     ...     ...                ...              ...         ...
# 765   3.033  101.45  Asia/Kuala_Lumpur            28800  1745751600
# 1544  3.033  101.45  Asia/Kuala_Lumpur            28800  1745755200
# 2462  3.033  101.45  Asia/Kuala_Lumpur            28800  1745758800
# 2835  3.033  101.45  Asia/Kuala_Lumpur            28800  1745762400
# 1693  3.033  101.45  Asia/Kuala_Lumpur            28800  1745766000
#
#          sunrise      sunset   temp  feels_like  pressure  ...  wind_speed  \
# 841   1735687143  1735730158  25.78       26.87      1012  ...        0.00
# 2516  1735687143  1735730158  25.53       26.59      1012  ...        1.03
# 2363  1735687143  1735730158  25.45       26.51      1011  ...        0.51
# 1988  1735687143  1735730158  25.15       26.18      1011  ...        0.00
# 466   1735687143  1735730158  24.98       25.99      1010  ...        1.03
# ...          ...         ...    ...         ...       ...  ...         ...
# 765   1745708719  1745752688  28.34       32.62      1008  ...        0.00
# 1544  1745708719  1745752688  27.23       30.81      1008  ...        0.51
# 2462  1745708719  1745752688  26.69       30.03      1009  ...        1.03
# 2835  1745708719  1745752688  26.69       30.12      1010  ...        0.00
# 1693  1745708719  1745752688  26.69       30.29      1010  ...        0.00
#
#       wind_deg  weather_id  weather_main  weather_desc  weather_icon  \
# 841          0         801        Clouds    few clouds           02n
# 2516         0         500          Rain    light rain           10n
# 2363         0         500          Rain    light rain           10n
# 1988         0         500          Rain    light rain           10n
# 466          0         500          Rain    light rain           10n
# ...        ...         ...           ...           ...           ...
# 765          0         500          Rain    light rain           10d
# 1544         0         801        Clouds    few clouds           02n
# 2462         0         801        Clouds    few clouds           02n
# 2835         0         801        Clouds    few clouds           02n
# 1693         0         801        Clouds    few clouds           02n
#
#                           utc8  month hour hour_stan
# 841  2025-01-01 00:00:00+08:00      1    0  0.000000
# 2516 2025-01-01 01:00:00+08:00      1    1  0.043478
# 2363 2025-01-01 02:00:00+08:00      1    2  0.086957
# 1988 2025-01-01 03:00:00+08:00      1    3  0.130435
# 466  2025-01-01 04:00:00+08:00      1    4  0.173913
# ...                        ...    ...  ...       ...
# 765  2025-04-27 19:00:00+08:00      4   19  0.826087
# 1544 2025-04-27 20:00:00+08:00      4   20  0.869565
# 2462 2025-04-27 21:00:00+08:00      4   21  0.913043
# 2835 2025-04-27 22:00:00+08:00      4   22  0.956522
# 1693 2025-04-27 23:00:00+08:00      4   23  1.000000
#
# [2903 rows x 25 columns]
